# %% [markdown]
# # TEA Plot

# %%
import tgx

# %% [markdown]
# ### 1. Load the dataset

# %%
data_path = '/network/scratch/r/razieh.shirzadkhani/'
dataset = tgx.data.mooc(root=data_path)
data = tgx.read_edgelist(data=dataset, discretize=True, intervals=51)
# Out:
# Number of loaded edges: 411749
# Available timestamps:  345600
# Discretizing data to 51 timestamps...
# Descritization Done..!

# %% [markdown]
# ### 2. Creat TEA plot

# %%
tgx.TEA(data, network_name=dataset.name)
# Out:
# Generating TEA plot...
# There are 51 timestamps.
# Plotting done!

# %%
tgx.TET(data, network_name=dataset.name)
# Out:
# Plotting TET plots...
# Info: Number of distinct edges (from index-edge map): 178443
# 51it [00:00, 621.50it/s]
# Info: edge-presence-matrix shape: (51, 178443)
# First level processing:
# Detecting edges present in train & test sets
# 100%|██████████| 43/43 [00:18<00:00,  2.30it/s]
# Detecting transductive edges (seen in train, repeating in test)
# 100%|██████████| 8/8 [00:05<00:00,  1.35it/s]
# Second level processing:
# Detecting edges 1) Only in train set, 2) only in test (inductive)
# 100%|██████████| 51/51 [00:18<00:00,  2.70it/s]
# Info: edge-presence-matrix shape: (51, 178443)
# Info: plotting edge presence heatmap for None ...
# Info: Border edge index: 148578
# Info: Test split timestamp value: 42
# Info: plotting done!
