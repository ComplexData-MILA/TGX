# %% [markdown]
# # TEA Plot

# %%
import tgx

# %% [markdown]
# ### 1. Load the dataset

# %%
data_path = '/network/scratch/r/razieh.shirzadkhani/'
dataset = tgx.data.mooc(root=data_path)
data = tgx.read_edgelist(data=dataset, discretize=True, intervals=51)
# Out:
# Number of loaded edges: 411749
# Available timestamps:  345600
# Discretizing data to 51 timestamps...
# Descritization Done..!

# %% [markdown]
# ### 2. Creat TEA plot

# %%
tgx.TEA(data, network_name=dataset.name)
# Out:
# Generating TEA plot...
# There are 51 timestamps.
# Plotting done!

# %%
tgx.TET(data, 
        network_name=dataset.name, 
        figsize = (9, 5),
        axis_title_font_size = 24,
        ticks_font_size = 24)
# Out:
# Plotting TET plots...
# Info: Number of distinct edges (from index-edge map): 178443
# 51it [00:00, 453.75it/s]
# Info: edge-presence-matrix shape: (51, 178443)
# First level processing:
# Detecting edges present in train & test sets
#  23%|██▎       | 10/43 [00:04<00:15,  2.19it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 tgx.TET(data,
#       2         network_name=dataset.name,
#       3         figsize = (9, 5),
#       4         axis_title_font_size = 20,
#       5         ticks_font_size = 22)
#
# File ~/TGX/tgx/visualizations/TET.py:53, in TET(temp_edgelist, filepath, intervals, network_name, add_frame, figsize, axis_title_font_size, ticks_font_size, axis_tick_gap, timestamp_split_cross_mark_offset)
#      51 print("Info: edge-presence-matrix shape: {}".format(e_presence_mat.shape))
#      52 # print(np.unique(e_presence_mat, return_counts=True))
# ---> 53 e_presence_mat, test_split_ts_value = process_presence_matrix(e_presence_mat, test_ratio_p=0.85)
#      54 print("Info: edge-presence-matrix shape: {}".format(e_presence_mat.shape))
#      55 # print(np.unique(e_presence_mat, return_counts=True))
#
# File ~/TGX/tgx/visualizations/TET.py:146, in process_presence_matrix(e_presence_matrix, test_ratio_p)
#     144 for tr_ts in tqdm(train_ts_list):
#     145     for eidx in range(num_unique_edges):
# --> 146         if e_presence_matrix[num_unique_ts - tr_ts - 1, eidx] == E_PRESENCE_GENERAL:
#     147             for test_ts_idx in range(test_split_ts_value + 1, num_unique_ts):
#     148                 if e_presence_matrix[num_unique_ts - test_ts_idx - 1, eidx] == E_PRESENCE_GENERAL:  # if seen in
#     149                     # the test set
#
# KeyboardInterrupt:
